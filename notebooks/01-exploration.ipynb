# %%
from gridcast.data_loading import scrape_data

df = scrape_data("2024-01-01", "2025-07-28")

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from gridcast.data_loading import scrape_data
#       3 df = scrape_data("2024-01-01", "2025-07-28")
#       5 df.head()
#
# File ~/Desktop/Projects/gridcast/gridcast/data_loading.py:57
#      51     """
#      52     Load data from the REN datahub.
#      53     """
#      54     pass
# ---> 57 scrape_data("2012-01-01", "2025-07-28")
#
# File ~/Desktop/Projects/gridcast/gridcast/data_loading.py:28, in scrape_data(start_date, end_date)
#       9 """
#      10 Scrape data from the REN datahub and optionally save it locally.
#      11
#    (...)     22     The scraped data.
#      23 """
#      24 url = (
#      25     f"https://datahub.ren.pt/service/download/csv/1354?startDateString={start_date}"
#      26     f"&endDateString={end_date}&culture=en-EN"
#      27 )
# ...
