# %%
from gridcast.data_loading import load_data
from gridcast.plotting import plot_daily_energy_stacked

df = load_data()
df.head()
# Out:
#           Data e Hora  Hídrica  Eólica  Solar  Biomassa  Ondas  \
# 0 2014-01-01 00:00:00   2045.2  1995.9    0.0     314.1    0.0
# 1 2014-01-01 00:15:00   2147.0  1950.5    0.0     314.4    0.0
# 2 2014-01-01 00:30:00   2155.5  1923.1    0.0     317.5    0.0
# 3 2014-01-01 00:45:00   2160.2  1911.7    0.0     312.3    0.0
# 4 2014-01-01 01:00:00   2014.2  1943.2    0.0     316.8    0.0
#
#    Gás Natural - Ciclo Combinado  Gás natural - Cogeração  Carvão  \
# 0                            0.0                    527.6   180.0
# 1                            0.0                    492.6   179.2
# 2                            0.0                    488.0   180.8
# 3                            0.0                    487.2   180.4
# 4                            0.0                    486.4   180.8
#
#    Outra Térmica  Importação  Exportação  Bombagem  Injeção de Baterias  \
# 0           44.9       187.1         0.0     175.6                  0.0
# ...

# %%
plot_daily_energy_stacked(df, "2025-07-31")

# %%
df.loc[df["Data e Hora"] == "2025-07-31 12:00:00"]
# Out:
#                Data e Hora  Hídrica  Eólica   Solar  Biomassa  Ondas  \
# 405984 2025-07-31 12:00:00     88.3   278.1  2919.5     296.2    0.0
#
#         Gás Natural - Ciclo Combinado  Gás natural - Cogeração  Carvão  \
# 405984                          909.2                    131.3     0.0
#
#         Outra Térmica  Importação  Exportação  Bombagem  Injeção de Baterias  \
# 405984           28.6      3489.2         0.0    1142.6                  0.0
#
#         Consumo Baterias  Consumo
# 405984               0.0   6984.5
